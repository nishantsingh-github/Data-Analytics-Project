# %%
#how to iport drive
from google.colab import drive

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/MyDrive/data /archive/IPL Matches 2008-2020.csv")

# %%
data.head(6)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
# 5  335987      Jaipur  2008-04-21       SR Watson
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
# 5                      Sawai Mansingh Stadium              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# ...

# %%
data.shape
# Out:
# (816, 17)

# %%
 batting_first= data[data['result_margin']!=0]

# %%
data.sample(5)
# Out:
#           id           city        date player_of_match  \
# 695  1136620         Mumbai  2018-05-27       SR Watson
# 781  1216517          Dubai  2020-10-18        KL Rahul
# 256   548314  Visakhapatnam  2012-04-09       RG Sharma
# 149   419140          Delhi  2010-04-04  PD Collingwood
# 278   548336         Jaipur  2012-04-23  AB de Villiers
#
#                                                  venue  neutral_venue  \
# 695                                   Wankhede Stadium              0
# 781                Dubai International Cricket Stadium              0
# 256  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...              0
# 149                                   Feroz Shah Kotla              0
# 278                             Sawai Mansingh Stadium              0
#
#                    team1                        team2          toss_winner  \
# 695  Chennai Super Kings          Sunrisers Hyderabad  Chennai Super Kings
# ...

# %%
plt.hist(data['result_margin'])
plt.title("nishant_ipl")
plt.figure(figsize=(5,7))

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
sns.boxplot(data['result_margin'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data['result_margin'].skew()
# Out:
# 2.692045194891035

# %%
pd.crosstab(data['winner'],data['toss_winner'])
# Out:
# toss_winner                  Chennai Super Kings  Deccan Chargers  \
# winner
# Chennai Super Kings                           61                2
# Deccan Chargers                                1               19
# Delhi Capitals                                 2                0
# Delhi Daredevils                               4                5
# Gujarat Lions                                  0                0
# Kings XI Punjab                                5                3
# Kochi Tuskers Kerala                           0                0
# Kolkata Knight Riders                          4                3
# Mumbai Indians                                 7                4
# Pune Warriors                                  1                1
# Rajasthan Royals                               5                3
# Rising Pune Supergiant                         0                0
# Rising Pune Supergiants                        0                0
# ...

# %%
sns.clustermap(pd.crosstab(data['winner'],data['toss_winner']))

# %%
date['date']=data('date').dt.week
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-98858f449bc4> in <module>
# ----> 1 date['date']=data('date').dt.week
#
# TypeError: 'DataFrame' object is not callable
