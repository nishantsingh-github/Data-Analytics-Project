# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/data /Diwali Sales Data.csv",encoding='latin1')

# %%
df = pd.DataFrame(df)

# %% [markdown]
#  # kn0w your data

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.sample(5)
# Out:
#        User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 342    1004050  Abhijeet  P00138542      F     36-45   43               1
# 2043   1003391      Rose  P00128742      F     18-25   20               0
# 11021  1002200   Dashyam  P00041342      F     36-45   41               0
# 3309   1000569   Turnell  P00137242      M     18-25   21               1
# 727    1003079    Akshay  P00135142      M     26-35   27               0
#
#                State      Zone    Occupation  Product_Category  Orders  \
# 342    Uttar Pradesh   Central          Govt  Footwear & Shoes       1
# 2043         Haryana  Northern      Aviation              Food       4
# 11021  Uttar Pradesh   Central  Construction            Beauty       4
# 3309   Uttar Pradesh   Central       Banking              Food       2
# 727    Uttar Pradesh   Central         Media              Food       2
#
#         Amount  Status  unnamed1
# 342    20276.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# # preprocessing (basic data cleaning)

# %%
df.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
df.drop(columns=['Status', 'unnamed1'],axis= 1,inplace=True)

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)
#2nd way to save data on run time is
#df_new =df.dropna() 
#jo bhi hum df me change karege  bh sab df_new m save hoga(not good b/c 2 bar dataframme ho gya to fir double memory lega)

# %%
#remove nan value from all data
df.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# change data type 
df['Amount']=df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df['Gender'].dtypes
# Out:
# dtype('O')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#remane columns dictonary paas karte h(ye save nii hoga b/c inplace=True us nii kiya h)
df.rename(columns={'Marital_Status': 'Shaadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
#df.describe()
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
 ax=sns.countplot(x='Gender' ,data = df)
 for bars in ax.containers:
  ax.bar_label(bars)

# %%
#df.groupby(['Gender'])['Amount'].sum()
df.groupby(['Gender'], as_index=False)['Amount'].sum()
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
gen=df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by = 'Amount', ascending=False)
sns.barplot(x='Gender',y='Amount',data = gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# * from above graph we see that most of the buyers are female and the purcheging power og female are more than the men .About (7ccr)

# %% [markdown]
# analysis on age columns

# %%
#gender vs  age
age=sns.countplot(x= 'Age Group',hue='Gender',data =df )

# %%
 #for plot the no on bars
age=sns.countplot(x= 'Age Group',hue='Gender',data =df )
for bars in  age.containers:
  age.bar_label(bars)

# %%
#total amount vs age group
tot =df.groupby(['Age Group'],as_index = False)['Amount'].sum().sort_values(by ='Amount', ascending = False)
sns.barplot(x= 'Age Group' ,y='Amount' ,data =tot)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# sabse jadha 26-35(females) saal bale logo ne ni h

# %% [markdown]
# # Analysiing STATES

# %%
#toatal orders fro top 10 states
sales_state = df.groupby(['State'],as_index= False)['Orders'].sum().sort_values(by ='Orders', ascending = False).head(10)
print(sales_state)
# Out:
#                State  Orders
# 14     Uttar Pradesh    4807
# 10       Maharashtra    3810
# 7          Karnataka    3240
# 2              Delhi    2740
# 9     Madhya Pradesh    2252
# 0     Andhra Pradesh    2051
# 5   Himachal Pradesh    1568
# 8             Kerala    1137
# 4            Haryana    1109
# 3            Gujarat    1066

# %%
sales_state = df.groupby(['State'],as_index= False)['Orders'].sum().sort_values(by ='Orders', ascending = False).head(10)
sns.barplot(x='State' ,y='Orders',data = sales_state)
sns.set(rc={'figure.figsize':(25,5)})

# %%
sales_state = df.groupby(['State'],as_index= False)['Amount'].sum().sort_values(by ='Amount', ascending = False).head(10)
print(sales_state)
# Out:
#                State    Amount
# 14     Uttar Pradesh  19374968
# 10       Maharashtra  14427543
# 7          Karnataka  13523540
# 2              Delhi  11603818
# 9     Madhya Pradesh   8101142
# 0     Andhra Pradesh   8037146
# 5   Himachal Pradesh   4963368
# 4            Haryana   4220175
# 1              Bihar   4022757
# 3            Gujarat   3946082

# %%
#top 10 ststes most amount
sales_state = df.groupby(['State'],as_index= False)['Amount'].sum().sort_values(by ='Amount', ascending = False).head(5)
sns.barplot(x='State' ,y='Amount',data = sales_state)
sns.set(rc={'figure.figsize':(10,5)})

# %% [markdown]
# # most of the orders from UP , Maharashtra, Karnatka

# %%
#mmariual Sstatus
ax=sns.countplot(x='Marital_Status',data =df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
sns.countplot(x= 'Marital_Status',hue = 'Gender',data =df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby(['Marital_Status','Gender'] ,as_index =False)['Amount'].sum()
# Out:
#    Marital_Status Gender    Amount
# 0               0      F  43786646
# 1               0      M  18338738
# 2               1      F  30549207
# 3               1      M  13574538

# %%
 marital =df.groupby(['Marital_Status','Gender'] ,as_index =False)['Amount'].sum()
 sns.barplot(x= 'Marital_Status',y= 'Amount',data= marital, hue = 'Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# from above fig we see most of the buyers are married womens

# %%
#occupation 
sns.set(rc={'figure.figsize': (25,5)})
ax=sns.countplot(x='Occupation',data =df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
 occu =marital =df.groupby(['Occupation'] ,as_index =False)['Amount'].sum().sort_values(by = 'Amount',ascending = False)
  
 sns.barplot(x= 'Occupation',y= 'Amount',data= marital)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# most purchage is IT ,Healthcare,Aviation

# %%
# product 
sns.countplot(x='Product_Category',data =df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#prodccu 
product =df.groupby(['Product_Category'] ,as_index =False)['Amount'].sum().sort_values(by = 'Amount',ascending = False).head(10)
  
sns.barplot(x= 'Product_Category',y= 'Amount',data= product)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# most sold product is food a than cclothing

# %%
#top selling produt
producttop =df.groupby(['Product_ID'] ,as_index =False)['Amount'].sum().sort_values(by = 'Amount',ascending = False).head(10)  
sns.barplot(x= 'Product_ID',y= 'Amount',data= producttop)
# Out:
# <Axes: xlabel='Product_ID', ylabel='Amount'>

# %% [markdown]
# CONLUSION
# married womens from UP and MAharashta working in IT ,Healthcare has more puchaging food and clothing
